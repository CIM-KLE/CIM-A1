# %%
import os

# %%
import glob

# %%
from IPython.display import Image, display

# %%
# !nvidia-smi

# %%
pip install -U ultralytics

# %%
import ultralytics

# %%
ultralytics.checks()

# %%
# !yolo task=detect mode=train model=yolov8s.pt data='/kaggle/input/flir-thermal-dataset-autorobo-self/data.yaml' epochs=100 imgsz=640

# %%
# !yolo task=detect mode=val model='/kaggle/working/runs/detect/train/weights/best.pt' data='/kaggle/input/flir-thermal-dataset-autorobo-self/data.yaml'

# %%
# !yolo task=detect mode=val model='/kaggle/working/runs/detect/train/weights/last.pt' data='/kaggle/input/flir-thermal-dataset-autorobo-self/data.yaml'

# %%
Image(filename = f"/kaggle/working/runs/detect/val2/confusion_matrix_normalized.png", height = 400)

# %%
Image(filename = f"/kaggle/working/runs/detect/train2/F1_curve.png", height = 500)

# %%
Image(filename = f"/kaggle/working/runs/detect/train2/results.png", height = 500)

# %%
Image(filename = f"/kaggle/input/flir-2024-dataset-yolov8-version/train/images/Back20-11-08_11-16-20-71_00001_jpg.rf.2ad360a209a96284624af1f544af87dc.jpg", height = 500)

# %% [markdown]
# **THIS IS FOR PREDICTING IN THE GIVEN SOURCE**

# %%
# !yolo task=detect mode=predict model='/kaggle/working/runs/detect/train/weights/last.pt' conf=0.25 source='/kaggle/input/flir-thermal-dataset-autorobo-self/test/images/FLIR_video_02663_jpeg.rf.3fa2706a4f03881f37ded692918f75ae.jpg'

# %%
Image(filename = f"/kaggle/working/runs/detect/predict/FLIR_video_00057_jpeg.rf.4fdb242ef1804492d80adbde6b78e835.jpg", height = 500)

# %%
Image(filename = f"/kaggle/working/runs/detect/predict2/FLIR_video_02663_jpeg.rf.3fa2706a4f03881f37ded692918f75ae.jpg", height = 500)

# %%
# !yolo task=detect mode=predict model='/kaggle/working/runs/detect/train/weights/best.pt' conf=0.25 source='/kaggle/input/flir-thermal-dataset-autorobo-self/test/images'

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# !cd /kaggle/working

# %%
# !ls

# %%
# !zip -r 150-Detects.zip /kaggle/working/runs/detect

# %%
# !rm -rf /kaggle/working/runs/detect/predict3

# %%
# !kaggle datasets download -d /kaggle/input/flir-thermal-dataset-autorobo-self -f /kaggle/input/flir-thermal-dataset-autorobo-self/test/images/FLIR_video_00057_jpeg.rf.4fdb242ef1804492d80adbde6b78e835.jpg
